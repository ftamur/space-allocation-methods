# %%
import pandas as pd

# %%
fat_time = pd.read_csv('output/fat_time.csv')
fat_operations = pd.read_csv('output/fat_operations.csv')

# %%
dt_time = pd.read_csv('output/dt_time.csv')
dt_operations = pd.read_csv('output/dt_operations.csv')

# %%
fat_time
# Out:
#                           File         Time
# 0     io/input_8_600_5_5_0.txt   433.902597
# 1  io/input_1024_200_5_9_9.txt  1817.852688
# 2  io/input_1024_200_9_0_0.txt  3641.570568
# 3  io/input_1024_200_9_0_9.txt   239.428139
# 4  io/input_2048_600_5_5_0.txt   951.165342

# %%
dt_time
# Out:
#                           File         Time
# 0     io/input_8_600_5_5_0.txt  2686.496210
# 1  io/input_1024_200_5_9_9.txt  5319.835901
# 2  io/input_1024_200_9_0_0.txt  1533.555317
# 3  io/input_1024_200_9_0_9.txt   368.715000
# 4  io/input_2048_600_5_5_0.txt  2755.776739

# %%
fat_operations
# Out:
#                           File  Create  Extend  Shrink  Access  \
# 0     io/input_8_600_5_5_0.txt     600     555       0     582
# 1  io/input_1024_200_5_9_9.txt     200    1396    1574     170
# 2  io/input_1024_200_9_0_0.txt     200       0       0  409113
# 3  io/input_1024_200_9_0_9.txt     200       0     833    1605
# 4  io/input_2048_600_5_5_0.txt     600     535       0     596
#
#    Create Rejected  Extend Rejected  Shrink Rejected  Access Rejected
# 0              332              317                0              117
# 1               27              377              275               12
# 2               79                0                0            48055
# 3                0                0              154               42
# 4              211              182                0               55

# %%
dt_operations
# Out:
#                           File  Create  Extend  Shrink  Access  \
# 0     io/input_8_600_5_5_0.txt     600     555       0     582
# 1  io/input_1024_200_5_9_9.txt     200    1396    1574     170
# 2  io/input_1024_200_9_0_0.txt     200       0       0  409113
# 3  io/input_1024_200_9_0_9.txt     200       0     833    1605
# 4  io/input_2048_600_5_5_0.txt     600     535       0     596
#
#    Create Rejected  Extend Rejected  Shrink Rejected  Access Rejected
# 0               72              555                0              209
# 1                0             1386              974              113
# 2               80                0                0           137110
# 3                0                0              154              208
# 4               72              535                0              203
